# %% [markdown]
# # Demo — Thinking Patterns
# Instancia patrones y genera aforismos contextuales.

# %%
from thinking_patterns.core.patterns_catalog import LoggingComoNarrativa, DocstringComoHipotesis, ModularizacionComoPensamiento
print(LoggingComoNarrativa().aplicar({"paso": "EDA", "decision": "usar winsorization", "evidencia": "menos skew"}))
print(DocstringComoHipotesis().aplicar({"funcion": "score_client()", "supuesto": "datos faltantes MCAR"}))
print(ModularizacionComoPensamiento().aplicar({"dominio": "reporte comercial"}))
